# %%
classes = ['Valid', 'Invalid']
sprite_width = 270
sprite_height = 270

# %%
with open('./classes.html', 'r') as fp:
    classes_template = fp.read()
with open('./table.html', 'r') as fp:
    table_template = fp.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-143-77a013a4314e> in <module>
# ----> 1 with open('./classes.html', 'r') as fp:
#       2     classes_template = fp.read()
#       3 with open('./table.html', 'r') as fp:
#       4     table_template = fp.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: './classes.html'

# %%
classes_html = ""
for class_name in classes:
    template = classes_template.replace('{{classname}}', class_name)
    classes_html += '\n' + ' '*16 + template
classes_html = classes_html.strip('\n').strip(' ')

# %%
table_html = table_template.replace('{{classes}}', classes_html)
table_html = table_html.replace('{{sprite-width}}', str(sprite_width))
table_html = table_html.replace('{{sprite-height}}', str(sprite_height))

# %%
with open('../static/table.html', 'w') as fp:
    fp.write(table_html)

# %%
src = "https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"

# %%
import urllib.request, urllib.error, urllib.parse

response = urllib.request.urlopen(src)
content = response.read().decode(response.headers.get_content_charset())

# %%
with open('index_template.html', 'r') as fp:
    index_template = fp.read()
    
index_out = index_template.replace('{{facets}}', content)

# %%
with open('index.html', 'w') as fp:
    fp.write(index_out)
